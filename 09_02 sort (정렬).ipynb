# %% [markdown]
# # 정렬 (Sort)
# ---
#
# ![sort](https://docs.tibco.com/pub/sfire-bauthor/7.5.0/doc/html/ko-KR/GUID-38D24175-9A0A-4A2B-A603-FC02F72AA8DB-display.png)
#
# - `어떤 기준`에 의해 값을 정렬
#     - ex: `오름차순` 기준이라면 값이 작은게 우선순위가 높고, 큰게 뒤로 간다
#     - ex: `내림차순` 기준이라면 값이 큰게 우선순위가 높고, 큰게 뒤로 간다

# %% [markdown]
# ---
# ## sort(), sorted()
# - sort() : 원본 변경
# - sorted() : 대상 변경 없이, 정렬된 결과 리턴
#
# ※위 정렬 함수는 `Timsort` 라는 정렬 알고리즘 사용

# %%
import random

myList = [
    random.randrange(1, 1000)
    for i in range(1000)
]

# %%
myList
# Out:
# [356,
#  949,
#  111,
#  622,
#  142,
#  536,
#  758,
#  996,
#  742,
#  62,
#  899,
#  228,
#  501,
#  319,
#  358,
#  121,
#  979,
#  834,
#  387,
#  184,
#  160,
#  177,
#  632,
#  638,
#  879,
#  86,
#  706,
#  455,
#  187,
#  752,
#  820,
#  309,
#  169,
#  520,
#  995,
#  232,
#  925,
#  415,
#  73,
#  384,
#  113,
#  831,
#  620,
#  601,
#  278,
#  100,
#  100,
#  4,
#  214,
#  739,
#  243,
#  224,
#  77,
#  9,
#  239,
#  185,
#  933,
#  18,
#  470,
#  355,
#  601,
#  288,
#  833,
#  121,
#  852,
#  41,
#  530,
#  527,
#  513,
#  496,
#  650,
#  403,
#  335,
#  861,
#  756,
#  185,
#  602,
#  632,
#  986,
#  659,
#  786,
#  348,
#  76,
#  178,
#  2,
#  797,
#  140,
#  630,
#  794,
#  429,
#  600,
#  894,
#  386,
#  660,
#  592,
#  223,
#  65,
#  870,
#  100,
#  115,
#  43,
#  533,
#  437,
#  837,
#  365,
#  279,
#  582,
#  538,
#  14,
#  245,
#  227,
#  163,
#  641,
#  400,
#  427,
#  480,
#  737,
#  924,
#  646,
#  95,
#  552,
#  567,
#  869,
#  711,
#  168,
#  664,
#  459,
# ...

# %%
random.shuffle(myList)
print('정렬전')
print(myList[:100])
# Out:
# 정렬전
# [679, 888, 342, 743, 484, 833, 937, 156, 620, 91, 341, 259, 118, 118, 938, 319, 350, 317, 942, 398, 326, 391, 271, 577, 533, 188, 70, 554, 859, 719, 360, 295, 382, 285, 968, 628, 79, 265, 867, 780, 254, 327, 960, 319, 21, 480, 986, 620, 986, 520, 288, 386, 507, 951, 386, 111, 125, 650, 87, 84, 868, 654, 750, 130, 597, 860, 542, 340, 850, 38, 687, 5, 986, 827, 758, 591, 635, 156, 390, 24, 612, 415, 17, 356, 660, 223, 788, 667, 437, 592, 446, 243, 852, 85, 852, 385, 117, 581, 25, 239]

# %%
myList.sort() #원본 변화 시킨다
print(myList[:100])
# Out:
# [1, 2, 2, 4, 4, 5, 5, 5, 6, 8, 9, 10, 11, 12, 12, 13, 14, 17, 18, 18, 18, 19, 21, 21, 22, 22, 24, 25, 25, 26, 27, 27, 28, 30, 33, 33, 34, 35, 35, 36, 38, 39, 41, 41, 42, 43, 43, 43, 43, 44, 45, 45, 47, 49, 50, 54, 55, 56, 57, 57, 57, 60, 62, 63, 65, 65, 65, 69, 70, 71, 73, 73, 73, 75, 76, 76, 77, 77, 77, 79, 84, 84, 84, 85, 86, 87, 88, 89, 91, 91, 91, 92, 93, 94, 95, 95, 96, 96, 98, 100]

# %%
random.shuffle(myList)
print('정렬전')
print(myList[:100])
# Out:
# 정렬전
# [179, 134, 982, 844, 599, 164, 541, 742, 899, 118, 530, 481, 472, 339, 323, 118, 351, 480, 84, 400, 778, 986, 57, 679, 674, 210, 743, 826, 859, 606, 650, 100, 94, 373, 254, 790, 292, 866, 350, 278, 204, 723, 201, 474, 783, 200, 262, 754, 374, 448, 319, 637, 122, 335, 545, 698, 553, 110, 346, 676, 291, 219, 361, 478, 602, 308, 131, 826, 512, 245, 833, 886, 116, 763, 186, 521, 386, 933, 4, 44, 63, 337, 786, 57, 973, 503, 771, 879, 688, 620, 396, 272, 364, 384, 532, 581, 316, 392, 971, 148]

# %%
print(sorted(myList)[:100]) #원본 myList를 변화시키진 않는다.

print('sorted() 후 myList')
print(myList[:100]) # 원본 변화 없다
# Out:
# [1, 2, 2, 4, 4, 5, 5, 5, 6, 8, 9, 10, 11, 12, 12, 13, 14, 17, 18, 18, 18, 19, 21, 21, 22, 22, 24, 25, 25, 26, 27, 27, 28, 30, 33, 33, 34, 35, 35, 36, 38, 39, 41, 41, 42, 43, 43, 43, 43, 44, 45, 45, 47, 49, 50, 54, 55, 56, 57, 57, 57, 60, 62, 63, 65, 65, 65, 69, 70, 71, 73, 73, 73, 75, 76, 76, 77, 77, 77, 79, 84, 84, 84, 85, 86, 87, 88, 89, 91, 91, 91, 92, 93, 94, 95, 95, 96, 96, 98, 100]
# sorted() 후 myList
# [179, 134, 982, 844, 599, 164, 541, 742, 899, 118, 530, 481, 472, 339, 323, 118, 351, 480, 84, 400, 778, 986, 57, 679, 674, 210, 743, 826, 859, 606, 650, 100, 94, 373, 254, 790, 292, 866, 350, 278, 204, 723, 201, 474, 783, 200, 262, 754, 374, 448, 319, 637, 122, 335, 545, 698, 553, 110, 346, 676, 291, 219, 361, 478, 602, 308, 131, 826, 512, 245, 833, 886, 116, 763, 186, 521, 386, 933, 4, 44, 63, 337, 786, 57, 973, 503, 771, 879, 688, 620, 396, 272, 364, 384, 532, 581, 316, 392, 971, 148]

# %% [markdown]
# # 정렬 알고리즘의 성능
# time complexity 는 다음 3가지로 귀결
#
# 1. **O(*n*<sup>2</sup>)**  <-- worst
# 1. **O(*n* log *n*)**    <-- average
# 1. **O(*n*)**          <-- impossible?
#
# > 특정 정렬 알고리즘의 성능이 항상 고정되어 있지 않다.   정렬하는 데이터의 분포 나 형태에 따라 성능이 달라질수 있다.     따라서,  각 알고리즘을 정확히 이해하고, 구현할줄 알며, 각각의 특성에 따라 어떠한 데이터 상황에서 정렬에 유리한지 알아야 한다.

# %% [markdown]
# # 다양한 정렬 알고리즘
#
# https://www.toptal.com/developers/sorting-algorithms  (시각화, 비교)
#
# ![sort](http://www.webappers.com/img/2009/04/sorting-algorithm.jpg)
#
#
# # 알고리즘 시각화 사이트
#
# https://visualgo.net/ko
#
# http://sorting.at/#

# %% [markdown]
# # 정렬및 검색 알고리즘 학습시..
#
# - 각 알고리즘에 대한 이해
# - 각 동작 사이클마다 값의 변화 (ex: 정렬상태의 변화)
# - 각 알고리즘의 성능에 대한 이해
#     - **best case** VS **worst case**
